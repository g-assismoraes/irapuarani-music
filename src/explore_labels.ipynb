# %%
import pandas as pd


df = pd.read_csv('data\\vgmidi_labelled.csv')

print(df['valence'].value_counts())
print(df['arousal'].value_counts())

df
# Out:
#  1    138
# -1     66
# Name: valence, dtype: int64
#  1    115
# -1     89
# Name: arousal, dtype: int64
#        id         series console           game  \
# 0    8013  Banjo-Kazooie     N64  Banjo-Kazooie
# 1    8073  Banjo-Kazooie     N64  Banjo-Kazooie
# 2    8029  Banjo-Kazooie     N64  Banjo-Kazooie
# 3    8022  Banjo-Kazooie     N64  Banjo-Kazooie
# 4    8066  Banjo-Kazooie     N64  Banjo-Kazooie
# ..    ...            ...     ...            ...
# 199  8135           Xeno     PS1      Xenogears
# 200  8101           Xeno     PS1      Xenogears
# 201  8177           Xeno     PS1      Xenogears
# 202  8173           Xeno     PS1      Xenogears
# 203  8149           Xeno     PS1      Xenogears
#
#                                         piece  \
# 0                          Boggys Igloo Happy
# 1                            Boggys Igloo Sad
# 2                           Bubblegloop Swamp
# 3                            Click Clock Wood
# ...
